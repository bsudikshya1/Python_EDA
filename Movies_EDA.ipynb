# %%
pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 9.5 MB/s eta 0:00:0000:0100:01m
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'/Users/sudikshyabhandari/Desktop/Takeo Bootcamp/Python Lec 4_EDA/movies2.csv')
df.head(10)
# Out:
#        id                original_title  \
# 0     278      The Shawshank Redemption
# 1     238                 The Godfather
# 2     240         The Godfather Part II
# 3     424              Schindler's List
# 4     389                  12 Angry Men
# 5   19404  दिलवाले दुल्हनिया ले जायेंगे
# 6     129                      千と千尋の神隠し
# 7     155               The Dark Knight
# 8  496243                           기생충
# 9     497                The Green Mile
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     116.038
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     167.834
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     164.908
# 3  The true story of how businessman Oskar Schind...   1993-12-15      77.039
# 4  The defense and the prosecution have rested an...   1957-04-10      76.566
# ...

# %%
# dropping orginial tile and overview columns
df= df.drop(['original_title','overview'], axis=1)
df.head(5)
# Out:
# <bound method DataFrame.info of           id release_date  popularity  vote_average  vote_count  \
# 0        278   1994-09-23     116.038         8.705       26221
# 1        238   1972-03-14     167.834         8.695       19877
# 2        240   1974-12-20     164.908         8.576       12001
# 3        424   1993-12-15      77.039         8.567       15409
# 4        389   1957-04-10      76.566         8.541        8276
# ...      ...          ...         ...           ...         ...
# 9395    9544   2002-08-09      14.975         3.724         346
# 9396  485774   2018-01-19      14.647         3.701        1317
# 9397   10870   2004-11-08      21.351         3.681         329
# 9398   74849   1978-11-17      11.516         3.300         441
# 9399    5491   2000-05-12      22.800         3.270         814
#
#                                             genre_names
# 0                                    ['Drama', 'Crime']
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9400 entries, 0 to 9399
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            9400 non-null   int64
#  1   release_date  9400 non-null   object
#  2   popularity    9400 non-null   float64
#  3   vote_average  9400 non-null   float64
#  4   vote_count    9400 non-null   int64
#  5   genre_names   9400 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 440.8+ KB

# %%
df.describe().round(0)
# Out:
#               id  popularity  vote_average  vote_count
# count     9400.0      9400.0        9400.0      9400.0
# mean    188625.0        43.0           7.0      1971.0
# std     250138.0        90.0           1.0      3092.0
# min          2.0         0.0           3.0       300.0
# 25%      10046.0        17.0           6.0       466.0
# 50%      36652.0        24.0           7.0       842.0
# 75%     344098.0        38.0           7.0      1966.0
# max    1212073.0      3629.0           9.0     35768.0

# %%
#dropcolomn,filter column
filtered_df = df[(df['vote_count'] > 5000) & (df['genre_names'] == "['Drama', 'Crime']")]
filtered_df.head(10)
# Out:
#           id release_date  popularity  vote_average  vote_count  \
# 0        278   1994-09-23     116.038         8.705       26221
# 1        238   1972-03-14     167.834         8.695       19877
# 2        240   1974-12-20     164.908         8.576       12001
# 15       769   1990-09-12     302.873         8.465       12419
# 26       598   2002-08-30     123.647         8.429        7086
# 29       311   1984-05-23      47.043         8.423        5183
# 320      640   2002-12-16      68.008         7.976       15175
# 329      627   1996-02-23      52.920         7.968        9382
# 1017    4982   2007-11-02      45.411         7.587        5194
# 3801  168672   2013-12-03      37.796         6.854        7072
#
#              genre_names
# 0     ['Drama', 'Crime']
# 1     ['Drama', 'Crime']
# 2     ['Drama', 'Crime']
# 15    ['Drama', 'Crime']
# 26    ['Drama', 'Crime']
# 29    ['Drama', 'Crime']
# 320   ['Drama', 'Crime']
# 329   ['Drama', 'Crime']
# ...

# %%
df.columns
# Out:
# Index(['id', 'release_date', 'popularity', 'vote_average', 'vote_count',
#        'genre_names'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                int64
# release_date     object
# popularity      float64
# vote_average    float64
# vote_count        int64
# genre_names      object
# dtype: object

# %%
df.shape
# Out:
# (9400, 6)

# %%
df.isnull().sum()
# Out:
# id              0
# release_date    0
# popularity      0
# vote_average    0
# vote_count      0
# genre_names     0
# dtype: int64

# %%
df.dropna()
# Out:
#           id release_date  popularity  vote_average  vote_count  \
# 0        278   1994-09-23     116.038         8.705       26221
# 1        238   1972-03-14     167.834         8.695       19877
# 2        240   1974-12-20     164.908         8.576       12001
# 3        424   1993-12-15      77.039         8.567       15409
# 4        389   1957-04-10      76.566         8.541        8276
# ...      ...          ...         ...           ...         ...
# 9395    9544   2002-08-09      14.975         3.724         346
# 9396  485774   2018-01-19      14.647         3.701        1317
# 9397   10870   2004-11-08      21.351         3.681         329
# 9398   74849   1978-11-17      11.516         3.300         441
# 9399    5491   2000-05-12      22.800         3.270         814
#
#                                             genre_names
# 0                                    ['Drama', 'Crime']
# 1                                    ['Drama', 'Crime']
# ...

# %%
df.duplicated().sum()
# Out:
# 48

# %%
df_filtered = df[['id','vote_count','vote_average']]
df_filtered
# Out:
#           id  vote_count  vote_average
# 0        278       26221         8.705
# 1        238       19877         8.695
# 2        240       12001         8.576
# 3        424       15409         8.567
# 4        389        8276         8.541
# ...      ...         ...           ...
# 9395    9544         346         3.724
# 9396  485774        1317         3.701
# 9397   10870         329         3.681
# 9398   74849         441         3.300
# 9399    5491         814         3.270
#
# [9400 rows x 3 columns]

# %%
#finding unique values in all the columns available in df
df.nunique()
# Out:
# id              9340
# release_date    5865
# popularity      8504
# vote_average    2948
# vote_count      3428
# genre_names     2036
# dtype: int64

# %%
# finding count of genre categories
df['genre_names'].value_counts().head(25)
# Out:
# genre_names
# ['Comedy']                                    556
# ['Drama']                                     538
# ['Drama', 'Romance']                          253
# ['Comedy', 'Romance']                         248
# ['Comedy', 'Drama']                           218
# ['Horror', 'Thriller']                        175
# ['Horror']                                    142
# ['Comedy', 'Drama', 'Romance']                138
# ['Drama', 'Thriller']                         124
# ['Drama', 'History']                          115
# ['Drama', 'Comedy']                           111
# ['Action', 'Thriller']                         91
# ['Romance', 'Comedy']                          82
# ['Crime', 'Drama', 'Thriller']                 81
# ['Action', 'Crime', 'Thriller']                78
# ['Crime', 'Drama']                             76
# ['Horror', 'Mystery', 'Thriller']              76
# ['Romance', 'Drama']                           74
# ...

# %%
# Select numerical columns (dtype='int64' or 'float64')
df_numerical = df.select_dtypes(include = ['int64', 'float64'])

# Select categorical columns (dtype='object')
df_categorical = df.select_dtypes(include='object')

# %%
df_numerical
# Out:
#           id  popularity  vote_average  vote_count
# 0        278     116.038         8.705       26221
# 1        238     167.834         8.695       19877
# 2        240     164.908         8.576       12001
# 3        424      77.039         8.567       15409
# 4        389      76.566         8.541        8276
# ...      ...         ...           ...         ...
# 9395    9544      14.975         3.724         346
# 9396  485774      14.647         3.701        1317
# 9397   10870      21.351         3.681         329
# 9398   74849      11.516         3.300         441
# 9399    5491      22.800         3.270         814
#
# [9400 rows x 4 columns]

# %%
df_numerical.corr()
# Out:
#                    id  popularity  vote_average  vote_count
# id            1.00000    0.121570      0.034430   -0.082670
# popularity    0.12157    1.000000      0.116467    0.322002
# vote_average  0.03443    0.116467      1.000000    0.280321
# vote_count   -0.08267    0.322002      0.280321    1.000000

# %%
#Analyzing dataframe with auto EDA
import sweetviz as sv
df_2 = pd.read_csv(r'/Users/sudikshyabhandari/Desktop/Takeo Bootcamp/Python Lec 4_EDA/movies2.csv')

report = sv.analyze(df_2)

#Generate a HTML report
report.show_html('report.html')
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
